# %%
import twstock as t
import pandas as p

stock = t.realtime.get("0050")
# print(stock['success'])

result = p.DataFrame(stock).T.iloc[1:3]
result.columns = ['股票代碼','地區','股票名稱','公司全名','現在時間','最新成交價','成交量','累計成交量','最佳五檔賣出價','最佳五檔賣出量','最佳五檔買進價','最佳五檔買進量','開盤價','最高價','最低價']
result
# Out:
#           股票代碼       地區    股票名稱              公司全名                 現在時間  \
# info      0050  0050.tw  元大台灣50  元大台灣卓越50證券投資信託基金  2024-05-14 06:30:00
# realtime   NaN      NaN     NaN               NaN                  NaN
#
#              最新成交價  成交量 累計成交量  \
# info           NaN  NaN   NaN
# realtime  164.4000  156  7697
#
#                                                     最佳五檔賣出價  \
# info                                                    NaN
# realtime  [164.3000, 164.2500, 164.2000, 164.1500, 164.1...
#
#                      最佳五檔賣出量  \
# info                     NaN
# realtime  [2, 10, 17, 26, 7]
#
#                                                     最佳五檔買進價  \
# info                                                    NaN
# realtime  [164.4000, 164.4500, 164.5000, 164.5500, 164.6...
#
#                         最佳五檔買進量       開盤價       最高價       最低價
# info                        NaN       NaN       NaN       NaN
# realtime  [10, 77, 161, 14, 19]  163.2000  164.4500  162.7000
